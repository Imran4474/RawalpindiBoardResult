# %%
import pandas as pd
import numpy as np
Medical = pd.read_csv('BiologyDataset.csv', delimiter='\t')
Engineering = pd.read_csv('PreEngineeringdata.csv', delimiter='\t')

# %%
del Engineering['Unnamed: 0']
del Medical['Unnamed: 0']

# %%
print Medical.shape
print Engineering.shape
print "Total Students", Medical.shape[0]+Engineering.shape[0]
# Out:
# (32403, 20)
# (31702, 20)
# Total Students 64105

# %%
print Medical.columns
# Out:
# Index([u'A-ID', u'BIOLOGY1', u'BIOLOGY2', u'BIOLOGY_prac', u'CHEMISTRY1',
#        u'CHEMISTRY2', u'CHEMISTRY_prac', u'ENGLISH1', u'ENGLISH2',
#        u'ISLAMIYAT1', u'ISLAMIYAT2', u'MATHEMATICS1', u'MATHEMATICS2',
#        u'PAKSTUDIES1', u'PAKSTUDIES2', u'PHYSICS1', u'PHYSICS2',
#        u'PHYSICS_prac', u'URDU1', u'URDU2'],
#       dtype='object')

# %%
Medical.head()
# Out:
#      A-ID  BIOLOGY1  BIOLOGY2  BIOLOGY_prac  CHEMISTRY1  CHEMISTRY2  \
# 0  801392        28        42           0.0          29          31
# 1  801408        38        47          23.0          27          39
# 2  801409        25        24          25.0          21          20
# 3  801410        22        26           0.0          37          45
# 4  801412        44        54          25.0          48          51
#
#    CHEMISTRY_prac  ENGLISH1  ENGLISH2  ISLAMIYAT1  ISLAMIYAT2  MATHEMATICS1  \
# 0             0.0        31      20.0          35          23            33
# 1            23.0        46      49.0          31          42            26
# 2            25.0        34      34.0          35          32            30
# 3             0.0        57      38.0          37          42            39
# 4            28.0        63      61.0          48          49            66
#
#    MATHEMATICS2  PAKSTUDIES1  PAKSTUDIES2  PHYSICS1  PHYSICS2  PHYSICS_prac  \
# ...

# %%
Medical.describe()
# Out:
#                A-ID      BIOLOGY1      BIOLOGY2  BIOLOGY_prac    CHEMISTRY1  \
# count  3.240300e+04  32403.000000  32403.000000  32403.000000  32403.000000
# mean  -2.846456e+14     36.238589     37.963923     23.526772     38.975280
# std    5.123858e+16     11.178138     12.962294      6.151743     11.906593
# min   -9.223372e+18      1.000000      2.000000      0.000000      2.000000
# 25%    8.293055e+05     27.000000     28.000000     21.000000     29.000000
# 50%    8.514260e+05     36.000000     38.000000     25.000000     39.000000
# 75%    8.798805e+05     45.000000     49.000000     28.000000     49.000000
# max    9.198370e+05     69.000000     73.000000     30.000000     73.000000
#
#          CHEMISTRY2  CHEMISTRY_prac      ENGLISH1      ENGLISH2    ISLAMIYAT1  \
# count  32403.000000    32403.000000  32403.000000  32403.000000  32403.000000
# mean      39.276055       23.665525     48.401876     47.722557     41.181002
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2)
fig.set_size_inches(10, 10)
#plt.figure(figsize=(10,8))
#print type(fig)
#fig[0].set_size_inches(15, 8)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
#sns.distplot(phydataset['PHYSICS1'],bins=10);
#sns.plt.title("Chemistry Mark Comparsion of Pre-Engineering and Pre-Medical Students")
#ax1.title.set_size(25)
ax1.set_title("Chemistry Marks Comparison",fontsize=18)
#ax.text(0.85, 0.85,'Text Here', fontsize=9)

b=sns.kdeplot(Medical['CHEMISTRY1'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['CHEMISTRY1'],label="Pre-Engineering Part1",ax = ax1)

c=sns.kdeplot(Medical['CHEMISTRY2'],label="Pre-Medical Part2",ax = ax2)
c=sns.kdeplot(Engineering['CHEMISTRY2'],label="Pre-Engineering Part2",ax = ax2)

b.set_xlabel("Marks",fontsize=10)
b.set_ylabel("Total Percentage",fontsize=10)
c.set_xlabel("Marks",fontsize=10)
c.set_ylabel("Total Percentage",fontsize=10)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2)
fig.set_size_inches(10, 10)
#plt.figure(figsize=(10,8))
#print type(fig)
#fig[0].set_size_inches(15, 8)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
#sns.distplot(phydataset['PHYSICS1'],bins=10);
#sns.plt.title("Chemistry Mark Comparsion of Pre-Engineering and Pre-Medical Students")
#ax1.title.set_size(25)
ax1.set_title("Physics Marks Comparison",fontsize=18)
#ax.text(0.85, 0.85,'Text Here', fontsize=9)

b=sns.kdeplot(Medical['PHYSICS1'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['PHYSICS1'],label="Pre-Engineering Part1",ax = ax1)

c=sns.kdeplot(Medical['PHYSICS2'],label="Pre-Medical Part2",ax = ax2)
c=sns.kdeplot(Engineering['PHYSICS2'],label="Pre-Engineering Part2",ax = ax2)

b.set_xlabel("Marks",fontsize=10)
b.set_ylabel("Total Percentage",fontsize=10)
c.set_xlabel("Marks",fontsize=10)
c.set_ylabel("Total Percentage",fontsize=10)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2)
fig.set_size_inches(10, 10)
#plt.figure(figsize=(10,8))
#print type(fig)
#fig[0].set_size_inches(15, 8)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
#sns.distplot(phydataset['PHYSICS1'],bins=10);
#sns.plt.title("Chemistry Mark Comparsion of Pre-Engineering and Pre-Medical Students")
#ax1.title.set_size(25)
ax1.set_title("MATHEMATICS Marks Comparison",fontsize=18)
#ax.text(0.85, 0.85,'Text Here', fontsize=9)

b=sns.kdeplot(Medical['MATHEMATICS1'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['MATHEMATICS1'],label="Pre-Engineering Part1",ax = ax1)

c=sns.kdeplot(Medical['MATHEMATICS2'],label="Pre-Medical Part2",ax = ax2)
c=sns.kdeplot(Engineering['MATHEMATICS2'],label="Pre-Engineering Part2",ax = ax2)

b.set_xlabel("Marks",fontsize=10)
b.set_ylabel("Total Percentage",fontsize=10)
c.set_xlabel("Marks",fontsize=10)
c.set_ylabel("Total Percentage",fontsize=10)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2)
fig.set_size_inches(10, 10)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
ax1.set_title("ENGLISH Marks Comparison",fontsize=18)
b=sns.kdeplot(Medical['ENGLISH1'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['ENGLISH1'],label="Pre-Engineering Part1",ax = ax1)
c=sns.kdeplot(Medical['ENGLISH2'],label="Pre-Medical Part2",ax = ax2)
c=sns.kdeplot(Engineering['ENGLISH2'],label="Pre-Engineering Part2",ax = ax2)
b.set_xlabel("Marks",fontsize=10)
b.set_ylabel("Total Percentage",fontsize=10)
c.set_xlabel("Marks",fontsize=10)
c.set_ylabel("Total Percentage",fontsize=10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2)
fig.set_size_inches(10, 10)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
ax1.set_title("Urdu Marks Comparison",fontsize=18)
b=sns.kdeplot(Medical['URDU1'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['URDU1'],label="Pre-Engineering Part1",ax = ax1)
c=sns.kdeplot(Medical['URDU2'],label="Pre-Medical Part2",ax = ax2)
c=sns.kdeplot(Engineering['URDU2'],label="Pre-Engineering Part2",ax = ax2)
b.set_xlabel("Marks",fontsize=10)
b.set_ylabel("Total Percentage",fontsize=10)
c.set_xlabel("Marks",fontsize=10)
c.set_ylabel("Total Percentage",fontsize=10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2)
fig.set_size_inches(10, 10)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
ax1.set_title("PAKISTAN STUDIES Marks Comparison",fontsize=18)
b=sns.kdeplot(Medical['PAKSTUDIES1'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['PAKSTUDIES1'],label="Pre-Engineering Part1",ax = ax1)
c=sns.kdeplot(Medical['PAKSTUDIES2'],label="Pre-Medical Part2",ax = ax2)
c=sns.kdeplot(Engineering['PAKSTUDIES2'],label="Pre-Engineering Part2",ax = ax2)
b.set_xlabel("Marks",fontsize=10)
b.set_ylabel("Total Percentage",fontsize=10)
c.set_xlabel("Marks",fontsize=10)
c.set_ylabel("Total Percentage",fontsize=10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1,ax2) = plt.subplots(2)
fig.set_size_inches(10, 10)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
ax1.set_title("ISLAMIYAT Marks Comparison",fontsize=18)
b=sns.kdeplot(Medical['ISLAMIYAT1'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['ISLAMIYAT1'],label="Pre-Engineering Part1",ax = ax1)
c=sns.kdeplot(Medical['ISLAMIYAT2'],label="Pre-Medical Part2",ax = ax2)
c=sns.kdeplot(Engineering['ISLAMIYAT2'],label="Pre-Engineering Part2",ax = ax2)
b.set_xlabel("Marks",fontsize=10)
b.set_ylabel("Total Percentage",fontsize=10)
c.set_xlabel("Marks",fontsize=10)
c.set_ylabel("Total Percentage",fontsize=10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1) = plt.subplots()
fig.set_size_inches(8, 8)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
ax1.set_title("PHYSICS PRACTICLE EXAMS Marks Comparison",fontsize=18)
b=sns.kdeplot(Medical['PHYSICS_prac'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['PHYSICS_prac'],label="Pre-Engineering Part1",ax = ax1)
b.set_xlabel("Marks",fontsize=10)
b.set_ylabel("Total Percentage",fontsize=10)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, (ax1) = plt.subplots()
fig.set_size_inches(8, 8)
sns.set(font_scale = 2.5)
sns.set(style="ticks", color_codes=True)
ax1.set_title("CHEMISTRY PRACTICAL EXAMS Marks Comparison",fontsize=18)
b=sns.kdeplot(Medical['CHEMISTRY_prac'],label="Pre-Medical Part1",ax = ax1)
b=sns.kdeplot(Engineering['CHEMISTRY_prac'],label="Pre-Engineering Part1",ax = ax1)
b.set_xlabel("Marks",fontsize=15)
b.set_ylabel("Total Percentage",fontsize=15)
plt.show()

# %%
Medical[(Medical.PHYSICS2-Medical.PHYSICS1>10)&(Medical.PHYSICS2>45)]
# Out:
#          A-ID  BIOLOGY1  BIOLOGY2  BIOLOGY_prac  CHEMISTRY1  CHEMISTRY2  \
# 3      801410        22        26           0.0          37          45
# 41     801569        44        56          29.0          46          55
# 84     801675        38        49          25.0          39          51
# 107    801768        43        50          25.0          30          54
# 111    801774        37        28          23.0          30          45
# 112    801775        38        28          30.0          30          44
# 132    801816        34        32          23.0          20          49
# 223    802666        28        49          25.0          20          25
# 270    802832        49        51          26.0          39          59
# 271    802834        52        54          29.0          46          60
# 289    802867        53        57          25.0          32          55
# 298    802883        56        53          30.0          47          60
# ...

# %%
Medical[Medical.CHEMISTRY2-Medical.CHEMISTRY1>10].shape
# Out:
# (5806, 20)

# %%
Medical[Medical.MATHEMATICS2-Medical.MATHEMATICS1>10].shape
# Out:
# (14483, 20)

# %%
Medical.shape
# Out:
# (32403, 20)

# %%
Engineering.shape
# Out:
# (31702, 20)

# %%
Engineering[Engineering.PHYSICS2-Engineering.PHYSICS1>10].shape
# Out:
# (3377, 20)

# %%
Engineering[Engineering.CHEMISTRY2-Engineering.CHEMISTRY1>10].shape
# Out:
# (5047, 20)

# %%
Engineering[Engineering.MATHEMATICS2-Engineering.MATHEMATICS1>10].shape
# Out:
# (13626, 20)

# %%
Medical.columns
# Out:
# Index([u'A-ID', u'BIOLOGY1', u'BIOLOGY2', u'BIOLOGY_prac', u'CHEMISTRY1',
#        u'CHEMISTRY2', u'CHEMISTRY_prac', u'ENGLISH1', u'ENGLISH2',
#        u'ISLAMIYAT1', u'ISLAMIYAT2', u'MATHEMATICS1', u'MATHEMATICS2',
#        u'PAKSTUDIES1', u'PAKSTUDIES2', u'PHYSICS1', u'PHYSICS2',
#        u'PHYSICS_prac', u'URDU1', u'URDU2'],
#       dtype='object')

# %%
import seaborn as sns; 
#sns.set(color_codes=True)
sns.regplot(x="A-ID", y="PHYSICS1", data=Medical)
plt.show()
